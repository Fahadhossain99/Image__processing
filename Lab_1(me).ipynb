# %%
import numpy as np
import cv2
img=cv2.imread("/content/me.jpg")

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1440x1440 at 0x7F059F7AE350>

# %%
print ('height: ', img.shape[0])
print ('width: ', img.shape[1])
# Out:
# height:  1440
# width:  1440

# %%
cv2.imwrite('new.jpg', img)
# Out:
# True

# %%
a = cv2.resize(img, (250,250))
cv2_imshow(a)
# Out:
# <PIL.Image.Image image mode=RGB size=250x250 at 0x7F059F72BBD0>
